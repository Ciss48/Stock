# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Data

# %%
stock_price = pd.read_csv('adjusted_stock_prices.csv')
stock_price
# Out:
#               Date Ticker   OpenPrice  ClosePrice    LowPrice   HighPrice  \
# 0       2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1       2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2       2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3       2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4       2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
# ...            ...    ...         ...         ...         ...         ...
# 851259  2016-12-30    ZBH  103.309998  103.199997  102.849998  103.930000
# 851260  2016-12-30   ZION   43.070000   43.040001   42.689999   43.310001
# 851261  2016-12-30    ZTS   53.639999   53.529999   53.270000   53.740002
# 851262  2016-12-30    AIV   44.730000   45.450001   44.410000   45.590000
# 851263  2016-12-30    FTV   54.200001   53.630001   53.389999   54.480000
#
#            Volume
# 0       2163600.0
# 1       2386400.0
# 2       2489500.0
# ...

# %% [markdown]
# - Ticker:  Mã chứng khoán của công ty
# - OpenPrice: Giá giao dịch đầu tiên của cổ phiếu khi thị trường mở cửa vào đầu phiên giao dịch.
# - ClosePrice: Giá giao dịch cuối cùng của cổ phiếu khi thị trường đóng cửa vào cuối phiên giao dịch.
# - Low Price (Giá thấp nhất): Mức giá thấp nhất mà cổ phiếu đạt được trong suốt phiên giao dịch.
# - High Price (Giá cao nhất): Mức giá cao nhất mà cổ phiếu đạt được trong suốt phiên giao dịch.
# - Volume (Khối lượng giao dịch): Tổng số lượng cổ phiếu được giao dịch trong suốt phiên giao dịch.

# %%
company_information = pd.read_csv('company_information.csv')
company_information
# Out:
#     Ticker               CompanyName SEC_Filings                  Sector  \
# 0      MCO              Moody's Corp     reports              Financials
# 1     HOLX                   Hologic     reports             Health Care
# 2      MRO        Marathon Oil Corp.     reports                  Energy
# 3        A  Agilent Technologies Inc     reports             Health Care
# 4     AKAM   Akamai Technologies Inc     reports  Information Technology
# ..     ...                       ...         ...                     ...
# 500   EBAY                 eBay Inc.     reports  Information Technology
# 501    ZBH    Zimmer Biomet Holdings     reports             Health Care
# 502   ENDP        Endo International     reports             Health Care
# 503    TMK           Torchmark Corp.     reports              Financials
# 504    JPM      JPMorgan Chase & Co.     reports              Financials
#
#                             SubIndustry         HeadquartersAddress  \
# ...

# %% [markdown]
# - Ticker: Mã chứng khoán của công ty
# - SEC_Filings: reports
# - Sector: Ngành công nghiệp chính mà công ty hoạt động. Ví dụ: Technology (Công nghệ).
# - SubIndustry: Ngành phụ hoặc lĩnh vực cụ thể hơn trong ngành công nghiệp chính. Ví dụ: Consumer Electronics (Điện tử tiêu dùng) có thể là một ngành phụ trong ngành Technology
# - HeadquartersAddress: Địa chỉ trụ sở chính của công ty.
# - DateAdded: Ngày mà công ty được thêm vào bảng hoặc danh sách, có thể là ngày bắt đầu niêm yết hoặc ngày mà thông tin công ty được cập nhật vào hệ thống.
# - CIK (Central Index Key): Mã số chỉ mục trung tâm do SEC cấp, được sử dụng để định danh duy nhất mỗi công ty trong hệ thống lưu trữ tài liệu của SEC.

# %%
financial_metrics = pd.read_csv('financial_metrics.csv')
financial_metrics
# Out:
#      Ticker   PeriodEnd    AccPayable  AccReceivable  AdditionalIncomeExpense  \
# 0       NEE  2014-12-31  2.504000e+09     -7000000.0              408000000.0
# 1       MAC  2012-12-31  8.159820e+08     -3735000.0              222167000.0
# 2        FE  2013-12-31  2.086000e+09   -114000000.0              -99000000.0
# 3       IFF  2015-12-31  3.472970e+08    -91712000.0               -3184000.0
# 4       MAS  2016-12-31  1.458000e+09   -120000000.0                6000000.0
# ...     ...         ...           ...            ...                      ...
# 1776    MUR  2013-12-31  2.558642e+09            0.0               77403000.0
# 1777    COO  2015-10-31  1.842850e+08     -4528000.0               -3083000.0
# 1778    PGR  2012-12-31  1.855500e+09   -333300000.0               -1800000.0
# 1779   ATVI  2013-12-31  9.910000e+08    198000000.0                      0.0
# 1780    MAR  2012-12-31  1.314000e+09            0.0               59000000.0
#
# ...

# %% [markdown]
# - PeriodEnd: Ngày kết thúc của kỳ báo cáo tài chính, thường là cuối năm hoặc cuối quý.
# - AccPayable (Accounts Payable): Khoản nợ phải trả của công ty đối với các nhà cung cấp. Một mức cao có thể cho thấy công ty đang có nhiều nợ ngắn hạn, ảnh hưởng đến dòng tiền và có thể làm giảm niềm tin của nhà đầu tư.
# - AccReceivable (Accounts Receivable):  Khoản phải thu từ khách hàng. Mức cao có thể cho thấy công ty bán hàng tốt, nhưng nếu quá cao có thể là dấu hiệu của việc khó thu hồi nợ.
# - AdditionalIncomeExpense: Thu nhập hoặc chi phí khác ngoài hoạt động kinh doanh chính. Khoản này có thể ảnh hưởng đến lợi nhuận cuối cùng của công ty.
# - AfterTaxROE (Return on Equity): Tỷ suất sinh lợi trên vốn chủ sở hữu sau thuế. Chỉ số này cao thường cho thấy công ty hoạt động hiệu quả, có thể làm tăng giá cổ phiếu.
# - CapEx (Capital Expenditure):  Chi phí vốn đầu tư vào tài sản cố định. Mức CapEx cao có thể chỉ ra rằng công ty đang đầu tư vào mở rộng hoặc cải thiện cơ sở hạ tầng, điều này có thể tích cực hoặc tiêu cực tùy thuộc vào khả năng sinh lợi từ đầu tư đó.
# - CapSurplus (Capital Surplus): Giá trị vốn thặng dư trên vốn cổ phần gốc. Thường phản ánh số tiền công ty thu được từ phát hành cổ phiếu trên giá trị danh nghĩa.
# - CashRatio: Tỷ lệ tiền mặt của công ty so với các khoản nợ ngắn hạn. Tỷ lệ cao cho thấy công ty có khả năng thanh toán các khoản nợ ngắn hạn tốt hơn, có thể ảnh hưởng tích cực đến cổ phiếu.
# - CashEquivalents: Tiền mặt và các tài sản tương đương tiền. Số dư cao cho thấy công ty có tính thanh khoản tốt, giúp giảm rủi ro tài chính.
# - CurrentAssetsTotal: Tổng tài sản ngắn hạn. Tài sản ngắn hạn cao có thể cung cấp một lớp bảo vệ trong trường hợp các khoản nợ ngắn hạn tăng lên.
# - CurrentLiabilitiesTotalz:  Tổng nợ ngắn hạn. Nếu nợ ngắn hạn quá cao, công ty có thể gặp khó khăn trong việc thanh toán nợ, điều này có thể ảnh hưởng xấu đến giá cổ phiếu.
# - TotalEquity: Tổng vốn chủ sở hữu. Thể hiện giá trị tài sản ròng thuộc về các cổ đông sau khi tất cả các khoản nợ được thanh toán.
# - TotalLiabilities: Tổng nợ phải trả. Một công ty có tổng nợ quá cao so với vốn chủ sở hữu có thể bị coi là rủi ro tài chính cao hơn.
# - LiabilitiesAndEquityTotal: Tổng giá trị của nợ phải trả và vốn chủ sở hữu. Chỉ số này phải cân đối với tổng tài sản của công ty.
# - TotalRevenue: Tổng doanh thu của công ty. Doanh thu cao thường là một dấu hiệu tích cực, cho thấy công ty có khả năng tạo ra doanh thu mạnh mẽ từ các hoạt động kinh doanh của mình.
# - TreasuryStock: Cổ phiếu quỹ do công ty mua lại. Mua lại cổ phiếu có thể làm giảm số lượng cổ phiếu lưu hành, tăng EPS (thu nhập trên mỗi cổ phiếu) và làm tăng giá cổ phiếu.
# - FiscalYear: Năm tài chính của dữ liệu
# - EPS (Earnings Per Share): Thu nhập trên mỗi cổ phiếu. Chỉ số này càng cao càng tốt, cho thấy mỗi cổ phiếu đại diện cho một phần lợi nhuận lớn hơn.
# - EstSharesOutstanding: Ước tính số cổ phiếu đang lưu hành. Số lượng cổ phiếu lưu hành tăng có thể làm loãng giá trị mỗi cổ phiếu.

# %% [markdown]
# # Data Exploration

# %%
# Shape of 3 table
print(stock_price.shape)
print(company_information.shape)
print(financial_metrics.shape)
# Out:
# (851264, 7)
# (505, 8)
# (1781, 78)

# %%
stock_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Date        851264 non-null  object
#  1   Ticker      851264 non-null  object
#  2   OpenPrice   851264 non-null  float64
#  3   ClosePrice  851264 non-null  float64
#  4   LowPrice    851264 non-null  float64
#  5   HighPrice   851264 non-null  float64
#  6   Volume      851264 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 45.5+ MB

# %%
company_information.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ticker               505 non-null    object
#  1   CompanyName          505 non-null    object
#  2   SEC_Filings          505 non-null    object
#  3   Sector               505 non-null    object
#  4   SubIndustry          505 non-null    object
#  5   HeadquartersAddress  505 non-null    object
#  6   DateAdded            307 non-null    object
#  7   CIK                  505 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 31.7+ KB

# %%
financial_metrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 78 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Ticker                     1781 non-null   object
#  1   PeriodEnd                  1781 non-null   object
#  2   AccPayable                 1781 non-null   float64
#  3   AccReceivable              1781 non-null   float64
#  4   AdditionalIncomeExpense    1781 non-null   float64
#  5   AfterTaxROE                1781 non-null   float64
#  6   CapEx                      1781 non-null   float64
#  7   CapSurplus                 1781 non-null   float64
#  8   CashRatio                  1482 non-null   float64
#  9   CashEquivalents            1781 non-null   float64
#  10  InventoryChanges           1781 non-null   float64
#  11  CommonStock                1781 non-null   float64
#  12  CostOfGoodsSold            1781 non-null   float64
# ...

# %%
#Kiem tra du lieu null cua company_information
company_information[company_information['DateAdded'].isnull() == True]
# Out:
#     Ticker                CompanyName SEC_Filings                  Sector  \
# 0      MCO               Moody's Corp     reports              Financials
# 3        A   Agilent Technologies Inc     reports             Health Care
# 5      TXN          Texas Instruments     reports  Information Technology
# 8     LLTC    Linear Technology Corp.     reports  Information Technology
# 11     FCX  Freeport-McMoran Cp & Gld     reports               Materials
# ..     ...                        ...         ...                     ...
# 491    HAL            Halliburton Co.     reports                  Energy
# 493    LEG            Leggett & Platt     reports             Industrials
# 498    STT         State Street Corp.     reports              Financials
# 500   EBAY                  eBay Inc.     reports  Information Technology
# 501    ZBH     Zimmer Biomet Holdings     reports             Health Care
#
#                         SubIndustry      HeadquartersAddress DateAdded  \
# ...

# %%
stock_price.describe()
# Out:
#            OpenPrice     ClosePrice       LowPrice      HighPrice  \
# count  851264.000000  851264.000000  851264.000000  851264.000000
# mean       64.993618      65.011913      64.336541      65.639748
# std        75.203893      75.201216      74.459518      75.906861
# min         1.660000       1.590000       1.500000       1.810000
# 25%        31.270000      31.292776      30.940001      31.620001
# 50%        48.459999      48.480000      47.970001      48.959999
# 75%        75.120003      75.139999      74.400002      75.849998
# max      1584.439941    1578.130005    1549.939941    1600.930054
#
#              Volume
# count  8.512640e+05
# mean   5.415113e+06
# std    1.249468e+07
# min    0.000000e+00
# 25%    1.221500e+06
# 50%    2.476250e+06
# 75%    5.222500e+06
# max    8.596434e+08

# %%
# Start date and end date 
print(min(stock_price['Date']))
print(max(stock_price['Date']))
# Out:
# 2010-01-04
# 2016-12-30

# %%
# Các công ty có trong data
unique_company = company_information[['Ticker', 'Sector']].drop_duplicates()
unique_company
# Out:
#     Ticker                  Sector
# 0      MCO              Financials
# 1     HOLX             Health Care
# 2      MRO                  Energy
# 3        A             Health Care
# 4     AKAM  Information Technology
# ..     ...                     ...
# 500   EBAY  Information Technology
# 501    ZBH             Health Care
# 502   ENDP             Health Care
# 503    TMK              Financials
# 504    JPM              Financials
#
# [505 rows x 2 columns]

# %%
sector_counts = unique_company.groupby('Sector')['Ticker'].count()
sector_counts
# Out:
# Sector
# Consumer Discretionary         85
# Consumer Staples               37
# Energy                         36
# Financials                     64
# Health Care                    59
# Industrials                    69
# Information Technology         68
# Materials                      25
# Real Estate                    29
# Telecommunications Services     5
# Utilities                      28
# Name: Ticker, dtype: int64

# %% [markdown]
# # Data Analysis

# %%
stock_price
# Out:
#               Date Ticker   OpenPrice  ClosePrice    LowPrice   HighPrice  \
# 0       2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1       2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2       2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3       2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4       2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
# ...            ...    ...         ...         ...         ...         ...
# 851259  2016-12-30    ZBH  103.309998  103.199997  102.849998  103.930000
# 851260  2016-12-30   ZION   43.070000   43.040001   42.689999   43.310001
# 851261  2016-12-30    ZTS   53.639999   53.529999   53.270000   53.740002
# 851262  2016-12-30    AIV   44.730000   45.450001   44.410000   45.590000
# 851263  2016-12-30    FTV   54.200001   53.630001   53.389999   54.480000
#
#            Volume
# 0       2163600.0
# 1       2386400.0
# 2       2489500.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Giả sử bạn đã đọc dữ liệu từ file CSV vào dataframe df
# df = pd.read_csv('path_to_your_file/unadjusted_prices.csv')

# Đếm số lần xuất hiện của mỗi mã cổ phiếu (Ticker)
ticker_counts = stock_price['Ticker'].value_counts()

# Lọc những mã cổ phiếu có tần suất >= 1750
top_tickers = ticker_counts[ticker_counts >= 1750].index

# Lọc dữ liệu của các mã cổ phiếu này
top_ticker_data = stock_price[stock_price['Ticker'].isin(top_tickers)]

# Tính toán sự phát triển mạnh bằng cách kiểm tra tỷ lệ thay đổi giá đóng cửa (ClosePrice)
ticker_growth = top_ticker_data.groupby('Ticker').apply(lambda x: (x['ClosePrice'].iloc[-1] - x['ClosePrice'].iloc[0]) / x['ClosePrice'].iloc[0])

# Đo lường tính ổn định bằng cách tính độ lệch chuẩn của giá đóng cửa
ticker_volatility = top_ticker_data.groupby('Ticker')['ClosePrice'].std()

# Lọc các mã cổ phiếu phát triển mạnh và ổn định
strong_stable_tickers = ticker_growth[(ticker_growth > 0.2) & (ticker_volatility < 10)]

# Trực quan hóa kết quả
plt.figure(figsize=(30, 6))
strong_stable_tickers.plot(kind='bar', color='green')
plt.title('Growth of Strong and Stable Tickers (Growth > 20%, Std < 10)')
plt.xlabel('Ticker')
plt.ylabel('Growth Rate')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10352\393261365.py:17: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ticker_growth = top_ticker_data.groupby('Ticker').apply(lambda x: (x['ClosePrice'].iloc[-1] - x['ClosePrice'].iloc[0]) / x['ClosePrice'].iloc[0])

# %%
# Sắp xếp theo tỷ lệ tăng trưởng và lấy ra 5 mã cổ phiếu cao nhất
top_5_tickers = strong_stable_tickers.sort_values(ascending=False).head(5)

# Trực quan hóa kết quả
plt.figure(figsize=(10, 6))
top_5_tickers.plot(kind='bar', color='green')
plt.title('Top 5 Strongest and Most Stable Tickers')
plt.xlabel('Ticker')
plt.ylabel('Growth Rate')
plt.xticks(rotation=45)
plt.show()

# %%
#Chọn ra 1 mã cổ phiếu tốt nhất để phân tích
HRL = stock_price[stock_price['Ticker'] == 'HRL']
HRL
# Out:
#               Date Ticker  OpenPrice  ClosePrice   LowPrice  HighPrice  \
# 464     2010-01-04    HRL   9.630000    9.570000   9.524999   9.642500
# 932     2010-01-05    HRL   9.577500    9.620000   9.505000   9.622500
# 1400    2010-01-06    HRL   9.649999    9.567500   9.537501   9.692500
# 1868    2010-01-07    HRL   9.587499    9.515000   9.442500   9.587499
# 2336    2010-01-08    HRL   9.475001    9.522500   9.447500   9.555000
# ...            ...    ...        ...         ...        ...        ...
# 848990  2016-12-23    HRL  35.110001   35.310001  34.910000  35.360001
# 849490  2016-12-27    HRL  35.330002   35.430000  35.099998  35.590000
# 849990  2016-12-28    HRL  35.349998   34.849998  34.759998  35.369999
# 850490  2016-12-29    HRL  34.939999   35.240002  34.910000  35.389999
# 850990  2016-12-30    HRL  35.240002   34.810001  34.669998  35.299999
#
#            Volume
# 464     2705200.0
# 932     1854400.0
# 1400    2583200.0
# 1868    2227200.0
# ...

# %%
HRL.set_index('Date', inplace=True)
HRL
# Out:
#            Ticker  OpenPrice  ClosePrice   LowPrice  HighPrice     Volume
# Date
# 2010-01-04    HRL   9.630000    9.570000   9.524999   9.642500  2705200.0
# 2010-01-05    HRL   9.577500    9.620000   9.505000   9.622500  1854400.0
# 2010-01-06    HRL   9.649999    9.567500   9.537501   9.692500  2583200.0
# 2010-01-07    HRL   9.587499    9.515000   9.442500   9.587499  2227200.0
# 2010-01-08    HRL   9.475001    9.522500   9.447500   9.555000  1298800.0
# ...           ...        ...         ...        ...        ...        ...
# 2016-12-23    HRL  35.110001   35.310001  34.910000  35.360001  1305900.0
# 2016-12-27    HRL  35.330002   35.430000  35.099998  35.590000  1387600.0
# 2016-12-28    HRL  35.349998   34.849998  34.759998  35.369999  1522100.0
# 2016-12-29    HRL  34.939999   35.240002  34.910000  35.389999  1202200.0
# 2016-12-30    HRL  35.240002   34.810001  34.669998  35.299999  1893600.0
#
# [1762 rows x 6 columns]

# %%
#Open price vs Close price of HRL
HRL['OpenPrice'].plot(label = 'HRL Open Price')
HRL['ClosePrice'].plot(label = 'HRL Close Price')
HRL['HighPrice'].plot(label = 'HRL High Price')
HRL['LowPrice'].plot(label = 'HRL Low Price')

plt.legend()
plt.show()

# %%
# Thiết lập cột 'Date' làm trục x
plt.figure(figsize=(10, 6))

plt.plot(HRL['Date'], HRL['OpenPrice'], label='HRL Open Price')
plt.plot(HRL['Date'], HRL['ClosePrice'], label='HRL Close Price')
plt.plot(HRL['Date'], HRL['HighPrice'], label='HRL High Price')
plt.plot(HRL['Date'], HRL['LowPrice'], label='HRL Low Price')

# Thêm tiêu đề, nhãn trục, và chú thích
plt.title('Open, Close, High, Low Prices of HRL Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

# Hiển thị biểu đồ
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 4
#       1 # Thiết lập cột 'Date' làm trục x
# ...

# %%
HRL['Volume'].plot(figsize = (17,5))
plt.title('Volumn Traded HRL')
plt.show()

# %%
# Lấy ra 5 mã tốt nhất 
HRL = stock_price[stock_price['Ticker'] == 'HRL']
NI = stock_price[stock_price['Ticker'] == 'NI']
HBAN = stock_price[stock_price['Ticker'] == 'HBAN']
HBI = stock_price[stock_price['Ticker'] == 'HBI']
ZION = stock_price[stock_price['Ticker'] == 'ZION']

# %%
HRL.set_index('Date', inplace=True)
NI.set_index('Date', inplace=True)
HBAN.set_index('Date', inplace=True)
HBI.set_index('Date', inplace=True)
ZION.set_index('Date', inplace=True)

# %%
plt.figure(figsize=(15, 7))
HRL['OpenPrice'].plot(label = 'HRL')
NI['OpenPrice'].plot(label = 'NI')
HBAN['OpenPrice'].plot(label = 'HBAN')
HBI['OpenPrice'].plot(label = 'HBI')
ZION['OpenPrice'].plot(label = 'ZION')
plt.title('Open Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 7))
HRL['Volume'].plot(label = 'HRL')
NI['Volume'].plot(label = 'NI')
HBAN['Volume'].plot(label = 'HBAN')
HBI['Volume'].plot(label = 'HBI')
ZION['Volume'].plot(label = 'ZION')
plt.title('Volume Traded')
plt.legend()
plt.show()

# %%
#HBAN có lượng giao dịch nhiều hơn hẳn nhưng Open Price lại thấp nhất 
#Kiểm tra kĩ đoạn HBAN nhô hẳn lên
HBAN.iloc[[HBAN['Volume'].argmax()]]
# Out:
#            Ticker  OpenPrice  ClosePrice  LowPrice  HighPrice       Volume
# Date
# 2010-12-14   HBAN       6.58         6.3      6.25       6.61  161746100.0

# %%
HBAN['Volume'].argmax()
# Out:
# 239

# %%
plt.figure(figsize=(15, 7))
# Tạo biểu đồ với kích thước phù hợp
ax = HBAN.iloc[200:300]['OpenPrice'].plot(label='HBAN Open Price', color='blue')

# Tạo trục y thứ hai và vẽ Volume trên đó
ax2 = ax.twinx()
HBAN.iloc[200:300]['Volume'].plot(ax=ax2, label='HBAN Volume', color='green')

# Thiết lập nhãn và tiêu đề cho biểu đồ
ax.set_xlabel('Index')
ax.set_ylabel('Open Price', color='blue')
ax2.set_ylabel('Volume', color='green')
ax.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.title('HBAN Open Price and Volume')

# Hiển thị biểu đồ
plt.show()

# %%
# Chưa có dữ liệu để hiển thị công ty nào thì giá trị hơn 
# Tạo thêm 1 cột là tổng số tiền giao dịch (Total money Traded)
HRL['Total_Traded'] = HRL['OpenPrice'] * HRL['Volume']
NI['Total_Traded'] = NI['OpenPrice'] * NI['Volume']
HBAN['Total_Traded'] = HBAN['OpenPrice'] * HBAN['Volume']
HBI['Total_Traded'] = HBI['OpenPrice'] * HBI['Volume']
ZION['Total_Traded'] = ZION['OpenPrice'] * ZION['Volume']
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10352\2052621421.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HRL['Total_Traded'] = HRL['OpenPrice'] * HRL['Volume']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10352\2052621421.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NI['Total_Traded'] = NI['OpenPrice'] * NI['Volume']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10352\2052621421.py:5: SettingWithCopyWarning:
# ...

# %%
plt.figure(figsize=(15, 7))
HRL['Total_Traded'].plot(label = 'HRL')
NI['Total_Traded'].plot(label = 'NI')
HBAN['Total_Traded'].plot(label = 'HBAN')
HBI['Total_Traded'].plot(label = 'HBI')
ZION['Total_Traded'].plot(label = 'ZION')
plt.title('Total_Traded')
plt.legend()
plt.show()

# %% [markdown]
# Ở biểu đồ Open Price, HRL thể hiện tốt nhất, nhưng đến tổng giao dịch thì có vẻ như đã có 1 giao dịch nào đó rất lơn diễn ra ở HBI trong khoảng 2014 -2015

# %%
#Kiểm tra
HBI['Total_Traded'].argmax()
# Out:
# 1311

# %%
HBI.iloc[[HBI['Total_Traded'].argmax()]]
# Out:
#            Ticker  OpenPrice  ClosePrice   LowPrice  HighPrice      Volume  \
# Date
# 2015-03-20    HBI  34.619999       34.18  34.080002  34.650002  63797500.0
#
#             Total_Traded
# Date
# 2015-03-20  2.208669e+09

# %%
plt.figure(figsize=(15, 7))
# Tạo biểu đồ với kích thước phù hợp
ax = HBI.iloc[1300:1350]['Total_Traded'].plot(label='HBI Total_Traded', color='blue')

# Tạo trục y thứ hai và vẽ Total_Traded trên đó
ax2 = ax.twinx()
HBI.iloc[1300:1350]['OpenPrice'].plot(ax=ax2, label='HBI Total_Traded', color='green')

# Thiết lập nhãn và tiêu đề cho biểu đồ
ax.set_xlabel('Index')
ax.set_ylabel('Total_Traded', color='blue')
ax2.set_ylabel('Open Price', color='green')
ax.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.title('HBI Open Price and Total_Traded')

# Hiển thị biểu đồ
plt.show()

# %%
#Moving average 
HRL['MA50'] = HRL['OpenPrice'].rolling(50).mean()
HRL['OpenPrice'].plot(figsize = (15,7))
HRL['MA50'].plot(label = 'MA50')
HRL['MA200'] = HRL['OpenPrice'].rolling(200).mean()
HRL['MA200'].plot(label = 'MA200')
plt.legend()
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10352\395239844.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HRL['MA50'] = HRL['OpenPrice'].rolling(50).mean()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10352\395239844.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HRL['MA200'] = HRL['OpenPrice'].rolling(200).mean()

# %% [markdown]
# 1. Nhận diện xu hướng:
# MA tăng: Nếu đường MA có xu hướng đi lên, đó là dấu hiệu của một xu hướng tăng (bullish).
# MA giảm: Nếu MA có xu hướng đi xuống, đó là dấu hiệu của một xu hướng giảm (bearish).
# Điều này giúp nhà đầu tư dễ dàng nhận diện được xu hướng chung của cổ phiếu hoặc thị trường, thay vì bị chi phối bởi những biến động giá ngắn hạn.
#
# 3. Xác định các mức hỗ trợ và kháng cự:
# MA thường được sử dụng để xác định các mức hỗ trợ (support) và kháng cự (resistance) tiềm năng:
#
# Hỗ trợ: Khi giá nằm trên đường MA, đường MA có thể hoạt động như một mức hỗ trợ, ngăn giá giảm sâu hơn.
# Kháng cự: Khi giá nằm dưới đường MA, đường MA có thể hoạt động như một mức kháng cự, ngăn giá tăng lên.
#
# 3. Tín hiệu mua bán
# MA còn có thể cung cấp các tín hiệu mua và bán khi sử dụng kết hợp với các chỉ báo khác hoặc giữa các loại MA:
#
# Golden Cross: Khi đường MA ngắn hạn (ví dụ: 50 ngày) cắt lên trên đường MA dài hạn (ví dụ: 200 ngày), đây là tín hiệu mua vì báo hiệu xu hướng tăng.
# Death Cross: Khi đường MA ngắn hạn cắt xuống dưới đường MA dài hạn, đây là tín hiệu bán vì báo hiệu xu hướng giảm.

# %% [markdown]
# # Phân tích tương quan

# %%
from pandas.plotting import scatter_matrix

# %%
five_best_comp = pd.concat([HRL['OpenPrice'],NI['OpenPrice'],HBAN['OpenPrice'],HBI['OpenPrice'],ZION['OpenPrice']],axis = 1)
five_best_comp.columns = ['HRL_Open','NI_Open','HBAN_Open','HBI_Open','ZION_Open']

# %%
scatter_matrix(five_best_comp, figsize = (8,8), hist_kwds = {'bins':50})
plt.show()

# %% [markdown]
#  - NI & HRL có mối tương quan rõ ràng nhất (positive correlation)

# %%
pip install mplfinance
# Out:
# ...
#    ---------------------------------------- 0.0/75.0 kB ? eta -:--:--
#    --------------------- ------------------ 41.0/75.0 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 75.0/75.0 kB 2.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Daily Percentage Change

# %% [markdown]
# $$
# r_t = \frac{p_t}{p_{t-1}} - 1
# $$

# %% [markdown]
# - r_t là lợi nhuận tại thời điểm t
# - p_t là giá tại thời điểm t
#
# Giá trị của report là để tính %lãi (hoặc lỗ), nó sẽ ko có ích cho việc dự đoán giá cổ phiếu tương lai, nhưng nó rất có ích trong biến động cổ phiếu -> Nếu daily percentage có mức phân bổ rộng thì cổ phiếu sẽ biến động nhiều hơn. Nhìn vào các biểu đồ về biến động sẽ có thể xem stock nào là ổn định nhất

# %%
HRL['returns'] = (HRL['ClosePrice']/HRL['ClosePrice'].shift(1)) - 1
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10352\3781455676.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HRL['returns'] = (HRL['ClosePrice']/HRL['ClosePrice'].shift(1)) - 1

# %%
HRL.head()
# Out:
#            Ticker  OpenPrice  ClosePrice  LowPrice  HighPrice     Volume  \
# Date
# 2010-01-04    HRL   9.630000      9.5700  9.524999   9.642500  2705200.0
# 2010-01-05    HRL   9.577500      9.6200  9.505000   9.622500  1854400.0
# 2010-01-06    HRL   9.649999      9.5675  9.537501   9.692500  2583200.0
# 2010-01-07    HRL   9.587499      9.5150  9.442500   9.587499  2227200.0
# 2010-01-08    HRL   9.475001      9.5225  9.447500   9.555000  1298800.0
#
#             Total_Traded  MA50  MA200   returns
# Date
# 2010-01-04  2.605108e+07   NaN    NaN       NaN
# 2010-01-05  1.776052e+07   NaN    NaN  0.005225
# 2010-01-06  2.492788e+07   NaN    NaN -0.005457
# 2010-01-07  2.135328e+07   NaN    NaN -0.005487
# 2010-01-08  1.230613e+07   NaN    NaN  0.000788

# %%
NI['returns'] = (NI['ClosePrice']/NI['ClosePrice'].shift(1)) - 1
HBAN['returns'] = (HBAN['ClosePrice']/HBAN['ClosePrice'].shift(1)) - 1
HBI['returns'] = (HBI['ClosePrice']/HBI['ClosePrice'].shift(1)) - 1
ZION['returns'] = (ZION['ClosePrice']/ZION['ClosePrice'].shift(1)) - 1
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10352\1224024549.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NI['returns'] = (NI['ClosePrice']/NI['ClosePrice'].shift(1)) - 1
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10352\1224024549.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HBAN['returns'] = (HBAN['ClosePrice']/HBAN['ClosePrice'].shift(1)) - 1
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10352\1224024549.py:3: SettingWithCopyWarning:
# ...

# %%
HRL['returns'].hist(bins = 50)
# Out:
# <Axes: >

# %%
HRL['returns'].hist(bins = 50, label = 'HRL', alpha = 0.8, figsize = (15,7))
NI['returns'].hist(bins = 50,label = 'NI', alpha = 0.9)
HBAN['returns'].hist(bins = 50,label = 'HBAN', alpha = 0.5)
HBI['returns'].hist(bins = 50,label = 'HBI', alpha = 0.2)
ZION['returns'].hist(bins = 50,label = 'ZION', alpha = 0.5)
plt.legend()
plt.show()

# %% [markdown]
# - ĐỒ thị càng rộng có nghĩa là cổ phiếu có càng nhiều biến động, ở đây có thể nói HBI có biến động nhiều nhất và NI là ổn định nhất

# %%
# phân phối mật độ xác suất (KDE - Kernel Density Estimate) của lợi nhuận (returns)
HRL['returns'].plot(kind = 'kde', label = 'HRL', figsize = (15,7))
NI['returns'].plot(kind = 'kde', label = 'NI')
HBAN['returns'].plot(kind = 'kde', label = 'HBAN')
HBI['returns'].plot(kind = 'kde', label = 'HBI')
ZION['returns'].plot(kind = 'kde', label = 'ZION')
plt.legend()
plt.show()

# %%
box_df = pd.concat([HRL['returns'], NI['returns'],HBAN['returns'],HBI['returns'], ZION['returns']], axis = 1)
box_df.columns = ['HRL','NI','HBAN','HBI','ZION']
box_df.plot(kind = 'box', figsize = (15,7))
# Out:
# <Axes: >

# %% [markdown]
# - HBAN, HBI, ZION biến động cổ phiếu nhiều hơn so với HRL và NI

# %%
scatter_matrix(box_df, figsize = (8,8), hist_kwds = {'bins':50}, alpha = 0.25)
plt.show()

# %% [markdown]
# - HBAN và ZION có sự tương quan thuận trong biến động cổ phiếu

# %% [markdown]
# ## Cumulative Return

# %% [markdown]
# Công thức tính lợi nhuận tích lũy (Cumulative Return)
# - r_t là % thay đổi hằng ngày (daily percentage change) ở công thức trên
# - i_t là ngày thứ t

# %% [markdown]
# $$
# i_t = (1 + r_t)i_{t-1} = \left( 1 + \frac{p_t}{p_{t-1}} - 1 \right)i_{t-1} = \frac{p_t}{p_{t-1}}i_{t-1}
# $$

# %%
HRL['Cummulative Return'] = (1 + HRL['returns']).cumprod()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10352\4153985631.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HRL['Cummulative Return'] = (1 + HRL['returns']).cumprod()

# %%
NI['Cummulative Return'] = (1 + NI['returns']).cumprod()
HBAN['Cummulative Return'] = (1 + HBAN['returns']).cumprod()
HBI['Cummulative Return'] = (1 + HBI['returns']).cumprod()
ZION['Cummulative Return'] = (1 + ZION['returns']).cumprod()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10352\3067917697.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NI['Cummulative Return'] = (1 + NI['returns']).cumprod()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10352\3067917697.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HBAN['Cummulative Return'] = (1 + HBAN['returns']).cumprod()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10352\3067917697.py:3: SettingWithCopyWarning:
# ...

# %%
HRL['Cummulative Return'].plot(label = 'HRL', figsize = (15,7))
NI['Cummulative Return'].plot(label = 'NI')
HBAN['Cummulative Return'].plot(label = 'HBAN')
HBI['Cummulative Return'].plot(label = 'HBI')
ZION['Cummulative Return'].plot(label = 'ZION')
plt.legend()
plt.title('Cummulative Return')
plt.show()

# %% [markdown]
# Biểu đồ trên trả lời cho câu hỏi: Cổ phiếu nào mang lại lợi nhuận cao nhất khi đầu tư ?
#
# Vào thời điểm cuối năm 2016, cả 5 cổ phiếu có % lợi nhuận ngang nhau nhưng nhìn chung HBI có mức lợi nhuận cao nhất trong khonarg 2013 - 2015

# %%
#Phân tích sự thay đổi giá cổ phiếu qua thời gian
plt.figure(figsize=(10,6))
plt.bar(stock_price['Ticker'], stock_price['Volume'], color='orange')
plt.title('Khối lượng giao dịch của các cổ phiếu')
plt.xlabel('Mã cổ phiếu')
plt.ylabel('Khối lượng giao dịch')
plt.xticks(rotation=90)
plt.show()

# %%
# Mối tương quan giữa EPS và ClosePrice
merged_data = pd.merge(stock_price, financial_metrics, on='Ticker')

# Vẽ biểu đồ scatter để xem mối quan hệ giữa EPS và ClosePrice
plt.figure(figsize=(10,6))
sns.scatterplot(data=merged_data, x='EPS', y='ClosePrice')
plt.title('Mối tương quan giữa EPS và giá đóng cửa')
plt.xlabel('EPS')
plt.ylabel('Giá đóng cửa')
plt.show()

# %%
# Khối lượng giao dịch và sự biến động của giá cổ phiếu
# Biểu đồ scatter giữa Volume và sự thay đổi giá trong ngày (HighPrice - LowPrice)
merged_data['PriceChange'] = merged_data['HighPrice'] - merged_data['LowPrice']

plt.figure(figsize=(10,6))
sns.scatterplot(data=merged_data, x='Volume', y='PriceChange')
plt.title('Khối lượng giao dịch và sự thay đổi giá trong ngày')
plt.xlabel('Khối lượng giao dịch')
plt.ylabel('Sự thay đổi giá (High - Low)')
plt.show()

# %%
# Phân tích giá cổ phiếu theo ngành
# Merge stock_price và company_information theo 'Ticker'
merged_data_with_sector = pd.merge(stock_price, company_information, on='Ticker')

# Vẽ biểu đồ boxplot để xem phân phối giá cổ phiếu theo ngành (Sector)
plt.figure(figsize=(12,8))
sns.boxplot(data=merged_data_with_sector, x='Sector', y='ClosePrice')
plt.title('Giá đóng cửa theo ngành công nghiệp')
plt.xticks(rotation=90)
plt.xlabel('Ngành công nghiệp')
plt.ylabel('Giá đóng cửa')
plt.show()

# %%
# Vẽ biểu đồ scatter giữa CapEx và ClosePrice
plt.figure(figsize=(10,6))
sns.scatterplot(data=merged_data, x='CapEx', y='ClosePrice')
plt.title('Ảnh hưởng của CapEx đến giá đóng cửa cổ phiếu')
plt.xlabel('CapEx')
plt.ylabel('Giá đóng cửa')
plt.show()

# %%
# Tương quan giữa CurrentLiabilitiesTotal và giá cổ phiếu
plt.figure(figsize=(10,6))
sns.scatterplot(data=merged_data, x='CurrentLiabilitiesTotal', y='ClosePrice')
plt.title('Mối tương quan giữa nợ ngắn hạn và giá đóng cửa')
plt.xlabel('Nợ ngắn hạn (Current Liabilities)')
plt.ylabel('Giá đóng cửa')
plt.show()

# %%
# Tạo DataFrame
df = pd.DataFrame(stock_price)

# Tính tỷ lệ tăng trưởng cho mỗi công ty trên từng ngày (growth rate)
df['GrowthRate'] = (df['ClosePrice'] - df['OpenPrice']) / df['OpenPrice']

# Lấy giá trị trung bình của mức tăng trưởng cho mỗi công ty (ticker) qua tất cả các ngày
df_growth = df.groupby('Ticker')['GrowthRate'].mean().reset_index()

# Sắp xếp tăng trưởng từ cao đến thấp
df_growth_sorted = df_growth.sort_values(by='GrowthRate', ascending=False)

# Lấy ra 3 công ty tăng trưởng cao nhất và 3 công ty tăng trưởng thấp nhất
top_3 = df_growth_sorted.head(3)
bottom_3 = df_growth_sorted.tail(3)

# Hiển thị kết quả
print("Top 3 công ty có mức tăng trưởng cao nhất:")
print(top_3)

print("\nTop 3 công ty có mức tăng trưởng kém nhất:")
print(bottom_3)
# Out:
# Top 3 công ty có mức tăng trưởng cao nhất:
#     Ticker  GrowthRate
# 225    HPE    0.002086
# 238   ILMN    0.001349
# 193    FTV    0.001329
#
# Top 3 công ty có mức tăng trưởng kém nhất:
#     Ticker  GrowthRate
# 192    FTR   -0.001150
# 190   FSLR   -0.001308
# 86     CHK   -0.001325
